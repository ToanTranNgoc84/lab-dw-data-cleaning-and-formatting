# %% [markdown]
# # Lab | Data Cleaning and Formatting

# %% [markdown]
# import pandas as pd
# url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
# insurance_company_df = pd.read_csv(url)
# display(insurance_company_df)In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
insurance_company_df = pd.read_csv(url)

#create a copy of DataFrame
insurance_company_df2 = insurance_company_df.copy()
display(insurance_company_df2)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 1: Data Cleaning and Formatting

# %% [markdown]
# ## Exercise 1: Cleaning Column Names

# %% [markdown]
# To ensure consistency and ease of use, standardize the column names of the dataframe. Start by taking a first look at the dataframe and identifying any column names that need to be modified. Use appropriate naming conventions and make sure that column names are descriptive and informative.
#
# *Hint*:
# - *Column names should be in lower case*
# - *White spaces in column names should be replaced by `_`*
# - *`st` could be replaced for `state`*

# %%
print("Cleaning Column Names")
print()


#st could be replaced for state, this order is important
insurance_company_df2.rename(columns={"ST": "state"}, inplace=True)

#Column names should be in lower case
insurance_company_df2.columns = insurance_company_df2.columns.str.lower()

#White spaces in column names should be replaced by _
insurance_company_df2.columns = insurance_company_df2.columns.str.replace(" ", "_")

display(insurance_company_df2)
# Out:
# Cleaning Column Names
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# ## Exercise 2: Cleaning invalid Values

# %% [markdown]
# The dataset contains columns with inconsistent and incorrect values that could affect the accuracy of our analysis. Therefore, we need to clean these columns to ensure that they only contain valid data.
#
# Note that this exercise will focus only on cleaning inconsistent values and will not involve handling null values (NaN or None).
#
# *Hint*:
# - *Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized, for example, to "M" and "F".*
# - *State abbreviations be can replaced with its full name, for example "AZ": "Arizona", "Cali": "California", "WA": "Washington"*
# - *In education, "Bachelors" could be replaced by "Bachelor"*
# - *In Customer Lifetime Value, delete the `%` character*
# - *In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"*

# %%
print("Cleaning invalid Values")

#value count for all columns
for column in insurance_company_df2.select_dtypes(include=['object']):
    print(f'\nColumn: {column}')
    display(insurance_company_df2[column].value_counts())
# Out:
# Cleaning invalid Values
#
# Column: customer
# customer
# RB50392    1
# HJ15383    1
# AO74776    1
# HQ82233    1
# OL72737    1
#           ..
# RO26085    1
# ES57969    1
# JK55587    1
# RN97635    1
# MY31220    1
# Name: count, Length: 1071, dtype: int64
# Column: state
# state
# California    331
# Oregon        320
# Arizona       211
# Washington    111
# Nevada         98
# Name: count, dtype: int64
# Column: gender
# gender
# F         474
# m         452
# female     28
# Name: count, dtype: int64
# Column: education
# education
# Bachelor                331
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Name: count, dtype: int64
# Column: number_of_open_complaints
# number_of_open_complaints
# 1/0/00    830
# 1/1/00    138
# 1/2/00     50
# 1/3/00     34
# 1/4/00     13
# 1/5/00      6
# Name: count, dtype: int64
# Column: policy_type
# policy_type
# Personal Auto     780
# ...

# %%
#Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized, for example, to "M" and "F".insurance_company_df2['gender'] = insurance_company_df2['gender'].str.lower().replace({'f': 'F', 'femal': 'F', 'male': 'M'})

#State abbreviations be can replaced with its full name, for example "AZ": "Arizona", "Cali": "California", "WA": "Washington"
state_mapping = {'AZ': 'Arizona', 'Cali': 'California', 'WA': 'Washington'}
insurance_company_df2['state'] = insurance_company_df2['state'].replace(state_mapping)

#In education, "Bachelors" could be replaced by "Bachelor"
insurance_company_df2['education'] = insurance_company_df2['education'].replace({'Bachelors': 'Bachelor'})

#In Customer Lifetime Value, delete the % character
# Convert customer_lifetime_value column to string
insurance_company_df2['customer_lifetime_value'] = insurance_company_df2['customer_lifetime_value'].astype(str)

# Clean customer lifetime value column
insurance_company_df2['customer_lifetime_value'] = insurance_company_df2['customer_lifetime_value'].str.replace('%', '')

#In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"
vehicle_class_mapping = {'Sports Car': 'Luxury', 'Luxury SUV': 'Luxury', 'Luxury Car': 'Luxury'}
insurance_company_df2['vehicle_class'] = insurance_company_df2['vehicle_class'].replace(vehicle_class_mapping)

display(insurance_company_df2)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      m              Bachelor
# 4     GA49547  Washington      m  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        nan      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
for column in insurance_company_df2.select_dtypes(include=['object']):
    print(f'\nColumn: {column}')
    display(insurance_company_df2[column].value_counts())
# Out:
# Column: customer
# customer
# RB50392    1
# HJ15383    1
# AO74776    1
# HQ82233    1
# OL72737    1
#           ..
# RO26085    1
# ES57969    1
# JK55587    1
# RN97635    1
# MY31220    1
# Name: count, Length: 1071, dtype: int64
# Column: state
# state
# California    331
# Oregon        320
# Arizona       211
# Washington    111
# Nevada         98
# Name: count, dtype: int64
# Column: gender
# gender
# F         474
# m         452
# female     28
# Name: count, dtype: int64
# Column: education
# education
# Bachelor                331
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Name: count, dtype: int64
# Column: number_of_open_complaints
# number_of_open_complaints
# 1/0/00    830
# 1/1/00    138
# 1/2/00     50
# 1/3/00     34
# 1/4/00     13
# 1/5/00      6
# Name: count, dtype: int64
# Column: policy_type
# policy_type
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# ...

# %% [markdown]
# ## Exercise 3: Formatting data types

# %% [markdown]
# The data types of many columns in the dataset appear to be incorrect. This could impact the accuracy of our analysis. To ensure accurate analysis, we need to correct the data types of these columns. Please update the data types of the columns as appropriate.

# %% [markdown]
# It is important to note that this exercise does not involve handling null values (NaN or None).

# %% [markdown]
# *Hint*:
# - *Customer lifetime value should be numeric*
# - *Number of open complaints has an incorrect format. Look at the different values it takes with `unique()` and take the middle value. As an example, 1/5/00 should be 5. Number of open complaints is a string - remember you can use `split()` to deal with it and take the number you need. Finally, since it should be numeric, cast the column to be in its proper type.*

# %%
"""#numeric_cols = ["customer_lifetime_value", "income", "monthly_premium_auto", "number_of_open_complaints", "total_claim_amount"]
#insurance_company_df2[numeric_cols] = insurance_company_df2[numeric_cols].astype(int)

#insurance_company_df2["customer_lifetime_value"] =pd.to.numeric(insurance_company_df2["customer_lifetime_value"], errors="coerce")

# Convert Customer lifetime value to numeric
insurance_company_df2["customer_lifetime_value"] = pd.to_numeric(insurance_company_df2["customer_lifetime_value"].str.replace("%", ""), errors="coerce")

# Extract the middle value from 'Number of Open Complaints' and convert to numeric
insurance_company_df2["number_of_open_complaints"] = insurance_company_df2["number_of_open_complaints"].str.split("/").str[1].astype(float)

# Convert all numeric variables to integers
numeric_cols = ["customer_lifetime_value", "income", "monthly_premium_auto", "number_of_open_complaints", "total_claim_amount"]
insurance_company_df2[numeric_cols] = insurance_company_df2[numeric_cols].astype(int)

# Display data types of all columns
print(insurance_company_df2.dtypes)
"""

# Replace 'nan' values with NaN
insurance_company_df2['customer_lifetime_value'] = insurance_company_df2['customer_lifetime_value'].replace('nan', np.nan)

# Convert customer_lifetime_value column back to numeric
insurance_company_df2['customer_lifetime_value'] = pd.to_numeric(insurance_company_df2['customer_lifetime_value'])

# Convert customer lifetime value to numeric, removing '%' character
#insurance_company_df2['customer_lifetime_value'] = insurance_company_df2['customer_lifetime_value'].str.replace('%', '').astype(float)

# Clean number of open complaints column
insurance_company_df2['number_of_open_complaints'] = insurance_company_df2['number_of_open_complaints'].apply(lambda x: x.split('/')[0] if isinstance(x, str) else x)
insurance_company_df2['number_of_open_complaints'] = pd.to_numeric(insurance_company_df2['number_of_open_complaints'])

display(insurance_company_df2)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      m              Bachelor
# 4     GA49547  Washington      m  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %% [markdown]
# ## Exercise 4: Dealing with Null values

# %% [markdown]
# Identify any columns with null or missing values. Identify how many null values each column has. You can use the `isnull()` function in pandas to find columns with null values.
#
# Decide on a strategy for handling the null values. There are several options, including:
#
# - Drop the rows or columns with null values
# - Fill the null values with a specific value (such as the column mean or median for numerical variables, and mode for categorical variables)
# - Fill the null values with the previous or next value in the column
# - Fill the null values based on a more complex algorithm or model (note: we haven't covered this yet)
#
# Implement your chosen strategy to handle the null values. You can use the `fillna()` function in pandas to fill null values or `dropna()` function to drop null values.
#
# Verify that your strategy has successfully handled the null values. You can use the `isnull()` function again to check if there are still null values in the dataset.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling null values.
#
# After formatting data types, as a last step, convert all the numeric variables to integers.

# %%
# Identify columns with null values and count the null values in each column
null_values = insurance_company_df2.isnull().sum()
print("Null values in each column:\n", null_values)
"""
#drop rows with more than 5 missing values
insurance_company_df2 = insurance_company_df2.dropna(thresh=5)
null_values_after = insurance_company_df2.isnull().sum()
print("Null values in each column:\n", null_values_after)


#Fill the null values with a specific value (such as the column mean or median for numerical variables, and mode for categorical variables)
insurance_company_df2.fillna(insurance_company_df2.mean(), inplace=True)

categorical_cols = ['gender', 'education', 'policy_type', 'vehicle_class']
for col in categorical_cols:
    insurance_company_df2[insurance_company_df2].fillna(df[insurance_company_df2].mode()[0], inplace=True)

# Identify columns with null values and count the null values in each column
null_values = insurance_company_df2.isnull().sum()
print("Null values in each column:\n", null_values)

# Strategy: Fill null values with column means for numerical variables and mode for categorical variables

# Fill null values with column means for numerical variables
numeric_cols = ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'total_claim_amount']
for col in numeric_cols:
    insurance_company_df2[col].fillna(insurance_company_df2[col].mean(), inplace=True)

# Verify if there are still any null values
null_values_after_fill = df.isnull().sum()
print("\nNull values in each column after filling null values:\n", null_values_after_fill)
"""
# Identify columns with null values
null_columns = insurance_company_df2.columns[insurance_company_df2.isnull().any()]
print(insurance_company_df2[null_columns].isnull().sum())

# Fill null values in specific columns
insurance_company_df2['number_of_open_complaints'].fillna(insurance_company_df2['number_of_open_complaints'].median(), inplace=True)
insurance_company_df2['customer_lifetime_value'].fillna(insurance_company_df2['customer_lifetime_value'].mean(), inplace=True)


display(insurance_company_df2)
# Out:
# Null values in each column:
#  customer                       0
# state                          0
# gender                       117
# education                      0
# customer_lifetime_value        0
# income                         0
# monthly_premium_auto           0
# number_of_open_complaints      0
# policy_type                    0
# vehicle_class                  0
# total_claim_amount             0
# dtype: int64
# gender    117
# dtype: int64
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      m              Bachelor
# 4     GA49547  Washington      m  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      m                Master
# 1067  VJ51327  California      F  High School or Below
# ...

# %% [markdown]
# ## Exercise 5: Dealing with duplicates

# %% [markdown]
# Use the `.duplicated()` method to identify any duplicate rows in the dataframe.
#
# Decide on a strategy for handling the duplicates. Options include:
# - Dropping all duplicate rows
# - Keeping only the first occurrence of each duplicated row
# - Keeping only the last occurrence of each duplicated row
# - Dropping duplicates based on a subset of columns
# - Dropping duplicates based on a specific column
#
# Implement your chosen strategy using the `drop_duplicates()` function.
#
# Verify that your strategy has successfully handled the duplicates by checking for duplicates again using `.duplicated()`.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling duplicates.
#
# Save the cleaned dataset to a new CSV file.
#
# *Hint*: *after dropping duplicates, reset the index to ensure consistency*.

# %%
#Use the .duplicated() method to identify any duplicate rows in the dataframe.
duplicate_rows = insurance_company_df2.duplicated()

#Dropping all duplicate rows, keeping only the first occurence of each duplicated row
insurance_company_df2.drop_duplicates(inplace=True)

#reset index
insurance_company_df2.reset_index(drop=True, inplace=True)

display(insurance_company_df2)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      m              Bachelor
# 4     GA49547  Washington      m  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      m                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                7.936903e+05      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %% [markdown]
# # Bonus: Challenge 2: creating functions on a separate `py` file

# %% [markdown]
# Put all the data cleaning and formatting steps into functions, and create a main function that performs all the cleaning and formatting.
#
# Write these functions in separate .py file(s). By putting these steps into functions, we can make the code more modular and easier to maintain.

# %% [markdown]
# *Hint: autoreload module is a utility module in Python that allows you to automatically reload modules in the current session when changes are made to the source code. This can be useful in situations where you are actively developing code and want to see the effects of changes you make without having to constantly restart the Python interpreter or Jupyter Notebook kernel.*

# %%
# In data_cleaning.py
import pandas as pd
import numpy as np

def clean_column_names(df):
    df.rename(columns={"ST": "state"}, inplace=True)
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace(" ", "_")
    return df

def clean_invalid_values(df):
    gender_mapping = {'f': 'F', 'femal': 'F', 'male': 'M'}
    state_mapping = {'AZ': 'Arizona', 'Cali': 'California', 'WA': 'Washington'}
    vehicle_class_mapping = {'Sports Car': 'Luxury', 'Luxury SUV': 'Luxury', 'Luxury Car': 'Luxury'}

    df['gender'] = df['gender'].str.lower().replace(gender_mapping)
    df['state'] = df['state'].replace(state_mapping)
    df['education'] = df['education'].replace({'Bachelors': 'Bachelor'})
    df['customer_lifetime_value'] = df['customer_lifetime_value'].str.replace('%', '')
    df['vehicle_class'] = df['vehicle_class'].replace(vehicle_class_mapping)
    
    return df

def format_data_types(df):
    df['customer_lifetime_value'] = df['customer_lifetime_value'].replace('nan', np.nan)
    df['customer_lifetime_value'] = pd.to_numeric(df['customer_lifetime_value'])
    df['number_of_open_complaints'] = df['number_of_open_complaints'].apply(lambda x: x.split('/')[0] if isinstance(x, str) else x)
    df['number_of_open_complaints'] = pd.to_numeric(df['number_of_open_complaints'])
    
    return df

def handle_null_values(df):
    df['number_of_open_complaints'].fillna(df['number_of_open_complaints'].median(), inplace=True)
    df['customer_lifetime_value'].fillna(df['customer_lifetime_value'].mean(), inplace=True)
    
    return df

def handle_duplicates(df):
    df.drop_duplicates(inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    return df

def main():
    # Load the dataset
    df = pd.read_csv("insurance_company_df2.csv")
    
    # Perform data cleaning and formatting
    insurance_company_df2 = clean_column_names(insurance_company_df2)
    insurance_company_df2 = clean_invalid_values(insurance_company_df2)
    insurance_company_df2 = format_data_types(insurance_company_df2)
    insurance_company_df2 = handle_null_values(insurance_company_df2)
    insurance_company_df2 = handle_duplicates(insurance_company_df2)
    
    # Save the cleaned dataset to a new CSV file
    insurance_company_df2.to_csv("cleaned_insurance_company_df2.csv", index=False)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[905], line 59
#      56     insurance_company_df2.to_csv("cleaned_insurance_company_df2.csv", index=False)
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[905], line 46, in main()
#      44 def main():
#      45     # Load the dataset
# ---> 46     df = pd.read_csv("insurance_company_df2.csv")
#      48     # Perform data cleaning and formatting
#      49     df = clean_column_names(insurance_company_df2)
#
# ...

# %% [markdown]
# # Bonus: Challenge 3: Analyzing Clean and Formated Data

# %% [markdown]
# You have been tasked with analyzing the data to identify potential areas for improving customer retention and profitability. Your goal is to identify customers with a high policy claim amount and a low customer lifetime value.
#
# In the Pandas Lab, we only looked at high policy claim amounts because we couldn't look into low customer lifetime values. If we had tried to work with that column, we wouldn't have been able to because customer lifetime value wasn't clean and in its proper format. So after cleaning and formatting the data, let's get some more interesting insights!
#
# Instructions:
#
# - Review the statistics again for total claim amount and customer lifetime value to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount and a low customer lifetime value. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount, and clients with a low customer lifetime value to be those in the bottom 25% of the customer lifetime value. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile and a customer lifetime value in the bottom 25th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount and low customer lifetime value data. To do so, select both columns of the dataframe simultaneously and pass it to the `.describe()` method. This will give you descriptive statistics, such as mean, median, standard deviation, minimum and maximum values for both columns at the same time, allowing you to compare and analyze their characteristics.

# %%
# Step 1: Calculate the 75th percentile of the total claim amount
claim_amount_75th_percentile = insurance_company_df2['total_claim_amount'].quantile(0.75)

# Step 2: Calculate the 25th percentile of the customer lifetime value
customer_lifetime_25th_percentile = insurance_company_df2['customer_lifetime_value'].quantile(0.25)

# Step 3: Filter the dataframe to include only customers who meet both criteria
high_claim_low_lifetime_df = insurance_company_df2[
    (insurance_company_df2['total_claim_amount'] > claim_amount_75th_percentile) &
    (insurance_company_df2['customer_lifetime_value'] < customer_lifetime_25th_percentile)
]

# Step 4: Calculate summary statistics for the filtered dataframe
summary_statistics = high_claim_low_lifetime_df[['total_claim_amount', 'customer_lifetime_value']].describe()

print(summary_statistics)
# Out:
#        total_claim_amount  customer_lifetime_value
# count           40.000000                40.000000
# mean           723.776577            341577.910000
# std            149.280606             56921.472027
# min            537.600000            228759.690000
# 25%            633.378846            304220.875000
# 50%            685.284189            365995.370000
# 75%            799.200000            387364.700000
# max           1185.988301            402381.440000
